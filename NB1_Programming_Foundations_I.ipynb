# %% [markdown]
# ### Programming for Science and Finance
#
# *Prof. Götz Pfeiffer, School of Mathematical and Statistical Sciences, University of Galway*

# %% [markdown]
# # Notebook 1: Programming Foundations I
#
# This notebook accompanies **Part I: Programming Foundations**. You will:
#
# * use Python as a **calculator**, and meet its numeric types and operators
# * understand **variables** and assignment, and the difference between a name and a value
# * wrap up simple programs as re-usable **functions** with parameters
# * apply **conditionals** and **loops** to control the flow of a program
# * recognize the common **errors** Python reports, and how to read them
#
# By the end of this notebook, you will be able to write and test simple Python code for scientific and financial contexts.

# %% [markdown]
# ## Task 1: Python as Calculator.
#
# Enter the following code and run it. Observe what happens.

# %%
2 + 2

# %%
3 * 7

# %%
100 / 3

# %% [markdown]
# Note the final digit: `100 / 3` is not exactly $33.333\dots$  A `float` is only an **approximation** of a real number, stored to about $16$ significant digits.  We come back to this in Notebook 3.

# %% [markdown]
# **Question:** What is the difference between `/` and `//` in Python?

# %%
100 // 3   # Try it here

# %% [markdown]
# ---
#
# **Exercises**
#
# 1. Compute the value of $2^{10}$.
# 2. Convert 100 °C to Fahrenheit.
#    (Formula: $F = 9/5 \cdot C + 32$)
# 3. How many seconds are there in a 365-day year?
#
# ---

# %% [markdown]
# ## Task 2: Variables, Values and Types.
#
# Python stores **values** in **variables**.  This process is called **assignment**.

# %%
principal = 1234    #  EUR 1234.- 
rate = 0.05         #  5%
years = 3           # 3 years

# %% [markdown]
# * All text after the `#` symbol counts as **comment**, not code.
# * Choosing **descriptive names** helps people to read your code.

# %%
mass = 2.0      # kg
velocity = 4.0  # m/s

# %% [markdown]
# In a code cell, type `print(mass)` or simply `mass` to see the value of `mass`.

# %%
print(mass)

# %%
mass

# %% [markdown]
# Values have **types**, variables don't.

# %%
x = 10    # int
y = 3.14  # float
name = "John"  # string

# %% [markdown]
# In a code cell, type `type(x)` to see the type of `x`.

# %%
type(x), type(y), type(name)

# %% [markdown]
# The type `str` deserves a closer look: a **string** is a **sequence** of characters.  Its length is given by `len()`, its characters can be accessed by **index** (counting from `0`, with negative indices counting from the end), two strings can be joined with `+`, and `in` tests whether one string occurs inside another.

# %%
print(len(name))      # 4
print(name[0])        # J (the first character)
print(name[-1])       # n (the last character)
print(name + " Doe")  # joining two strings
print("oh" in name)   # True

# %% [markdown]
# Values can be **converted** from one type into another, by the built-in functions `int()`, `float()` and `str()`.  This matters because the same operator can mean different things for different types: `+` adds numbers, but joins strings.

# %%
print("1234" + "5432")            # 12345432 (two strings joined)
print(int("1234") + int("5432"))  # 6666 (two numbers added)
print(float("2.5") + 1)           # 3.5
print("EUR " + str(1234))         # EUR 1234

# %% [markdown]
# ---
# **Exercises**
#
# 1. Store your age in a variable `age` and compute the number of months.
# 2. Assign values to `a = 3`, `b = 7`, then compute $a^2 + b^2$.
# 3. Write code that swaps the values of two variables `x` and `y`.
# 4. What is the difference between `"1234" + "5432"` and `int("1234") + int("5432")`?
#    Explain why the same operator `+` gives two different answers.
# 5. Store your own name in a variable `name`, and print its length, its first and its last
#    character, and whether the letter `"a"` occurs in it.
#
# ---

# %% [markdown]
# ## Task 3: Arithmetic, Expressions.
#
# Python supports standard math operations and more.
#
# An **expression** is a valid combination of values, variables and operators that represents a new value.

# %%
print(2 + 3)   # 5
print(2 * 3)   # 6
print(14 / 4)  # 3.5
print(14 // 4) # 3 (integer quotient)
print(14 % 4)  # 2 (remainder: 14 is 3 * 4 + 2)
print(2 ** 3)  # 8 (power)

# %% [markdown]
# Types matter in expressions:  the sum of two `int` values is a value of type `int`, the sum of two `float` values is a value of type `float`.

# %%
2.0 + 3.0

# %% [markdown]
# ### Operator Precedence.
#
# When an expression contains several operators, the order in which they are applied is fixed by **operator precedence** -- the rule known from school as **BOMDAS**: brackets first, then orders (powers), then multiplication and division, and finally addition and subtraction.  Python follows the same convention, so a formula can usually be typed much as it is written on paper.

# %% [markdown]
# **Example:** Kinetic Energy.  Formula: $E = \frac12 m v^2$, here for a sliotar of mass $m = 0.115$ kg, travelling at $v = 40$ m/s (about $144$ km/h).

# %%
m = 0.115   # kg
v = 40.0    # m/s
E = 1/2 * m * v**2
print("Energy:", E)

# %% [markdown]
# Here the power `v**2` is evaluated before the products, just like you would read the original formula.  Had the multiplications been carried out first, as in `(1/2 * m * v)**2`, the answer would have been `5.29` rather than `92.0`.
#
# When in doubt, add brackets: they cost nothing, and they make the intended reading visible to whoever reads the code next.

# %% [markdown]
# ### Built-in Functions.
#
# Besides operators, Python provides a number of **built-in functions** that are always available, without any `import`.  You have met `print()` and `type()` already.  The ones used most often in this course are
#
# * `round(x, n)`: the value of `x`, rounded to `n` decimal places,
# * `abs(x)`: the absolute value of `x`,
# * `len(s)`: the number of elements of `s` (a string here, a list in Notebook 2),
# * `min(...)` and `max(...)`: the smallest and the largest of several values,
# * `sum(...)`: the total of a list of values (Notebook 2).

# %%
print(round(100/3, 2))              # 33.33
print(abs(-7))                      # 7
print(len("finance"))               # 7
print(min(3, 1, 2), max(3, 1, 2))   # 1 3

# %% [markdown]
# **Example:** Compound Interest.  Formula: $A = P(1+r)^t$.

# %%
P = 1234.00
r = 0.05
t = 3
A = P * (1 + r) ** t
print(round(A, 2))

# %% [markdown]
# ### Formatted Output.
#
# Printing a comma separated list of values is quick, but the result of a computation with floating point numbers is often unreadable, like `1428.50925` for an amount of money.  The built-in function `round()` helps, but there is a better way.
#
# An **f-string** is a string prefixed with the letter `f`, in which an expression enclosed in curly braces `{}` is replaced by its value.  A **format specification**, after a colon `:` inside the braces, says how to display that value.  Here `.2f` means: as a decimal number with exactly `2` digits after the point.

# %%
print(f"After {t} years, the value is EUR {A:.2f}")
print(f"Unformatted, that would be {A}")
print(f"Any expression can go inside the braces: {2 * A:.2f}")

# %% [markdown]
# ---
# **Exercises**
#
# 1. Predict the value of each of `2 + 3 * 4**2`, `(2 + 3) * 4**2` and `8 / 2 * 4`,
#    then check your predictions with Python.
#    For `a = 3` and `b = 8`, what does `a + b / 2` compute?  How do you write $\frac{a+b}{2}$ correctly?
# 2. A share was bought at EUR 24.75 and sold at EUR 21.30.
#    Use `abs()` and `round()` to print the size of the loss, to two decimal places.
#    Then use `min()` and `max()` to report the lower and the higher of the two prices.
# 3. With `P = 2500`, `r = 0.037` and `t = 7`, compute `A = P * (1 + r)**t` and use a **single**
#    f-string to print `An investment of EUR 2500 grows to EUR 3223.97 in 7 years.`
#    Then print the rate as a percentage with one decimal place, i.e. as `3.7%`.
# 4. A satellite in a circular orbit of radius $r$ around the Earth travels at speed
#    $v = \sqrt{G M / r}$, where $G = 6.674 \times 10^{-11}$ and $M = 5.972 \times 10^{24}$ kg.
#    The International Space Station orbits $400$ km above the surface, and the Earth's radius
#    is $6371$ km.  Compute its speed with `(G * M / r) ** 0.5` and print it in km/s to two
#    decimal places.  What happens if you drop the brackets, and why?
# 5. The **Schwarzschild radius** of a body of mass $M$ is $r_s = 2 G M / c^2$, where
#    $c = 2.998 \times 10^8$ m/s is the speed of light: compressed to a ball of this radius, the
#    body would become a black hole.  Compute it for the Sun, of mass $1.989 \times 10^{30}$ kg,
#    and print the answer in km.  Then evaluate `(2 * G * M / c)**2` as well, and explain why
#    the two results are so wildly different.
#
#
# ---

# %% [markdown]
# ## Task 4: Programs and Functions.
#
# A **program** is a list of instructions, usually executed step by step.

# %% [markdown]
# **Example:** Investment Growth.  Formula: $A = P (1 +r)^t$, as before.

# %%
P = 1234                                         # I
r = 0.03                                         # I 
t = 5                                            # I 
A = P * (1 + r)**t                               # P
print("After", t, "years, the value is EUR", round(A, 2))  # O

# %% [markdown]
# This program consists of 3 parts, marked as `I` (Input), `P` (Process), `O` (Output).

# %% [markdown]
# Some functions, like the exponential function `exp()`, are defined in the `math` standard library.  This library needs to be imported before such a function can be used.

# %% [markdown]
# **Example:** Population Growth.  Formula: $P(t) = P_0 e^{rt}$.

# %%
import math

P0 = 100                                     # I
r = 0.2                                      # I  
t = 10                                       # I
P = P0 * math.exp(r * t)                     # P
print(f"Population after {t} years is {P:.2f}")  # O

# %% [markdown]
# This program, too, has three parts: `I`, `P` and `O`.

# %% [markdown]
# ---
# **Exercises**
#
# 1. Mark the `I`, `P` and `O` parts of the Population Growth program above.  Which lines would you change to model a population that *shrinks* by $5\%$ per year?
# 2. Besides `exp`, the `math` library provides `math.sqrt`, `math.log` and the constant `math.pi`.  Use them to compute the circumference $2 \pi r$ and the area $\pi r^2$ of a circle of radius $r = 2.5$.
# 3. Write a program in the same `I`/`P`/`O` shape that converts a distance in miles into kilometres (one mile is $1.60934$ km).
#
# ---

# %% [markdown]
# ## Functions and Function Calls.
#
# A **function** is a **named** piece of reusable code with **input parameters** and a **return statement** for output.
#
# A **function definition statement** has the general form (syntax):
#
# ```python
# def function_name(parameters):
#     function_body
#     return result
# ```

# %% [markdown]
# So it consists of
# * a **header** line
#     * starting with a **keyword** (`def`),
#     * followed by the **name** given to the function,
#     * the comma separated list of **parameters**, enclosed in parentheses `()`,
#     * ending in a **colon** (`:`)
# * and a **body** of
#     * a list of **statements**
#     * including a **return** statement at the end
#     * all indented by the same amount of significant whitespace.

# %% [markdown]
# **Example:** the square function $f(x) = x^2$.

# %%
def square(x):
    x2 = x * x
    return x2

# %% [markdown]
# ... or simply ...

# %%
def square(x):
    return x * x

# %% [markdown]
# **Example:** Future Value $A = P (1 + r)^t$

# %%
def future_value(P, r, t):
    A = P * (1 + r)**t
    return A

# %% [markdown]
# **Example:** Kinetic Energy $E = \frac12 m v^2$.

# %%
def kinetic_energy(mass, velocity):
    energy = 1/2 * mass * velocity**2
    return energy

# %% [markdown]
# A **function call expression** has the form `function_name(arguments)`, i.e.,
# * the function's **name** followed by
# * a comma separated list of **arguments**, matching and serving as values for the parameters of the function's definition.

# %%
square(5)

# %%
future_value(1234, 0.03, 5)

# %%
kinetic_energy(3.0, 4.0)

# %% [markdown]
# ### Local Variables.
#
# The parameters of a function, and any variables assigned in its body, are **local** to that function: they exist only while the function is running, and they have nothing to do with variables of the same name outside.  In `future_value(P, r, t)` above, the parameters `P`, `r` and `t` are not the variables `P`, `r` and `t` that were assigned earlier in this notebook.
#
# This is what makes a function **reusable**: it communicates with the rest of the program only through its **arguments** and its **return value**.
#
# A function whose body has no `return` statement still returns a value: the special value `None`, which stands for "nothing".

# %%
P = 1000
print(future_value(1234, 0.03, 5))  # the function works with its own P
print(P)                            # the P out here is unchanged

# %% [markdown]
# ---
# **Exercises**
#
# 1. Write a function `cube(x)` that returns $x^3$. Test it with 2, 5, and 10.
# 2. Write a function `convert(celsius)` that returns the Fahrenheit equivalent.  Test it with 20, 30 and 100 degrees Celsius.
# 3. Write a function `compound(principal, rate, periods)` that computes compounding interest. Test it with EUR 500 at 3.5% over 10 years.
#
# 4. Predict what the following prints, then run it:
#    ```python
#    t = 99
#    print(future_value(1000, 0.05, 3))
#    print(t)
#    ```
#    Why is `t` unchanged?  And what does a function return if its body has no `return` statement?
#
# ---

# %% [markdown]
# ## Flow of Control.

# %% [markdown]
# Sometimes sequential execution of the instructions in a program needs to be modified.  Real world problems require **decisions** (branching) and **repetition** (loops).
#
# In Science, you might want to simulate a particle until a given boundary is crossed.
#
# In Finance, you might want to rebalance a portfolio only if today's return is negative.

# %% [markdown]
# ## Task 5: Boolean Logic and Comparisons.
#
# The **boolean values** `True` and `False` allow us to ask questions inside the code.

# %%
type(True), type(False)

# %% [markdown]
# There are a number of **comparison operators** that result in either `True` or `False`.

# %%
print(5 > 3)    # True
print(5 < 3)    # False
print(5 >= 3)   # True
print(5 <= 3)   # False
print(5 == 3)   # False (equals!)
print(5 != 3)   # True (not equals)

# %% [markdown]
# They can be combined with **logical operators**.

# %%
x = 5
print((x > 0) and (x < 10))   # True
print((x < 0) or (x > 10))    # False
print(not (x == 5))           # False

# %% [markdown]
# ---
# **Exercises**
#
# 1. Predict the value of each of `3 == 3.0`, `"3" == 3` and `1 < 2 < 3`, then check with Python.
# 2. With `x = 7`, evaluate `(x > 0) and (x % 2 == 0)` and `not (x > 0 or x < -10)`.  Say in words what each one asks about `x`.
# 3. An account is in good standing if its balance is at least EUR $0$ **and** the account is not frozen.  With variables `balance` and `frozen`, write one boolean expression that is `True` exactly then.
#
# ---

# %% [markdown]
# ## Task 6: Conditionals ...
#
# ... aka `if` statements.  Conditionals allow us to conditionally execute parts of the code.

# %% [markdown]
# General Form (syntax):
#
# ```python
# if condition:
#     body
# elif other_condition:
#     body
# else:
#     body
# ```

# %% [markdown]
# **Example:** Revenue Classifier.

# %%
def revenue_class(revenue):
    if revenue < 0:
        result = "Loss"
    elif revenue > 0:
        result = "Profit"
    else:
        result = "Break Even"
    return result

# %%
revenue_class(-5)

# %% [markdown]
# An `if` statement is a kind of **compound statement**. It consists of
# * possibly more than one **header** line, each
#     * starting with a keyword (`if`, `elif` or `else`) and
#     * ending with a colon (`:`)
# * each followed by a **body** of one or more statements.
#
# The first header is always the `if` clause.
#
# Then there can be zero or more `elif` clauses, as needed.
#
# And finally there can be one `else` clause.
#
# The `if` clause and the `elif` clauses all have conditions attached.  Only the body under the first condition that is met will be executed, with the body of the `else` clause as default in case that none of the conditions is met.

# %% [markdown]
# ### Conditional Expressions.
#
# Sometimes it is a **value** that depends on a condition, rather than the flow of the program.  For this, python has the **conditional expression**
#
# ```python
# value_if_true if condition else value_if_false
# ```
#
# Unlike an `if` statement, this is an **expression**: it has a value, and can be used wherever a value is expected.

# %%
n = 7
parity = "even" if n % 2 == 0 else "odd"
print(parity)

# %%
def sign(x):
    return -1 if x < 0 else 1

print(sign(-5), sign(5))

# %% [markdown]
# ---
# **Exercises**
#
# 1. Write code that prints “even” if a number `n` is even, and “odd” otherwise.
# 2. Store a temperature in Celsius and print whether water would be “solid”, “liquid”, or “gas” at that temperature.
# 3. A bank gives a bonus if a balance exceeds €10,000. Write a conditional to add €100 if the balance qualifies.
#
# 4. Rewrite exercise 1 as a **conditional expression**, assigning the answer to a variable
#    `parity` rather than printing it.  Why can a conditional expression not replace the
#    `if` statement in exercise 3?
#
# ---

# %% [markdown]
# ## Recursion.
#
# The body of a function may contain calls to other functions -- including a call to the very function that is being defined.  Such a function is called **recursive**.  For this to work, and to eventually come to an end, a recursive function needs
#
# * at least one **base case**, which returns a value without calling itself, and
# * a **recursive case**, which calls itself with arguments that are closer to a base case.
#
# **Example:** the factorial $n! = 1 \cdot 2 \cdots n$ satisfies $0! = 1$ (the base case) and $n! = n \cdot (n-1)!$ (the recursive case).

# %%
def factorial(n):
    if n == 0:
        return 1
    return n * factorial(n - 1)

print(factorial(5))   # 120 = 1 * 2 * 3 * 4 * 5

# %% [markdown]
# With a conditional expression, the same function fits on a single line.

# %%
def factorial(n):
    return 1 if n == 0 else n * factorial(n - 1)

print(factorial(10))

# %% [markdown]
# ---
# **Exercises**
#
# 1. What happens when you call `factorial(-1)`?  Why?
# 2. Write a recursive function `power(x, n)` that computes $x^n$ for a non-negative whole number `n`, without using the operator `**`.
# 3. Euclid's algorithm computes the greatest common divisor of two numbers `a` and `b` as follows: if `b` is `0`, the answer is `a`; otherwise it is the greatest common divisor of `b` and `a % b`.  Write a recursive function `gcd(a, b)` that implements this, and test it with `gcd(60, 24)`.
# ---

# %% [markdown]
# ## Loops (Repetition).

# %% [markdown]
# Loop statements are used to execute the same part of the code several times.
#
# Python supports two kinds of loops, **definite** and **indefinite** loops.

# %% [markdown]
# ## Task 7: Definite Loops ...
#
# ... aka `for` loops.
#
# Repeat code a given number of times.

# %% [markdown]
# General Form (syntax):
#
# ```python
# for variable in values:
#     body
# ```

# %%
for i in range(5):
    print("Step", i)

# %% [markdown]
# Here `range(5)` stands for the numbers `0,1,2,3,4`, counting from `0` and excluding `5`.  Strictly speaking it is not a list -- evaluating `range(5)` just echoes `range(0, 5)` -- but `list(range(5))` turns it into one.
#
# With two arguments, `range(m, n)` counts from `m` instead of `0`, again excluding `n`.  A third argument gives the step size.

# %%
print(list(range(5)))         # [0, 1, 2, 3, 4]
print(list(range(1, 6)))      # [1, 2, 3, 4, 5]
print(list(range(0, 10, 2)))  # [0, 2, 4, 6, 8]

# %% [markdown]
# A `for` loop statement consists of
# * a **header** line
#     * starting with a keyword (`for`)
#     * followed by a loop variable (`i`)
#     * the keyword `in` and
#     * a **list** of values (`range(5)`)
#     * ending with a colon (`:`)
# * followed by a **body** of one or more statements.
#
# The body of instructions is executed once for each value in the given list, assigned to the loop variable for temporary use.

# %% [markdown]
# **Example:** Compound Interest, Year by Year.

# %%
def compound_interest(P, r, t):
    for year in range(1, t+1):
        P = P * (1 + r)
        print("Year", year, ":", round(P, 2))
    return P

# %%
compound_interest(1234, 0.03, 5)

# %% [markdown]
# ---
# **Exercises**
#
# 1. Print the numbers from 1 to 10 using a `for` loop.
# 2. Write a loop that prints the square of each integer from 1 to 20.
# 3. What do `range(3, 12)`, `range(0, 20, 5)` and `range(10, 0, -2)` stand for?  Turn each into a list to find out.
# 4. Use a `for` loop to add up the numbers from 1 to 100: start with `total = 0`, and add to it inside the loop.
#
# ---

# %% [markdown]
# ## Task 8: Indefinite Loops ...
#
# ... aka `while` loops.
#
# Repeat code until some condition fails.

# %% [markdown]
# General Form (syntax):
#
# ```python
# while condition:
#     body
# ```
#
# A `while` statement consists of
# * a **header** line that
#     * starts with a keyword (`while`)
#     * followed by a condition (a boolean expression)
#     * and ends with a colon (`:`)
# * and a **body** of one or more statements.
#
# The body of statements is executed over and over until the condition is no longer `True`.

# %% [markdown]
# **Example:** How long does it take for an investment to double in value?

# %%
P = 1234
r = 0.04
t = 0
A = P
while A < 2*P:
    A *= (1 + r)
    t += 1
print("doubling time:", t, "years")

# %% [markdown]
# ... or simply

# %%
r = 0.04
t = 0
A = 1
while A < 2:
    A *= (1 + r)
    t += 1
print("doubling time:", t, "years")

# %% [markdown]
# **Exercise:** convert this re-usable program into a function.

# %% [markdown]
# **Fun Fact.**  By the [Rule of 72](https://en.wikipedia.org/wiki/Rule_of_72), the doubling time at rate $r$% is roughly $72/r$.  Check: $72/4$ is $18$. $\checkmark$
# (The exact formula would be $t = \ln(2)/\ln(1 +r)$.)

# %% [markdown]
# **Example:** Bacterial Growth up to a given Threshold.

# %%
N = 100
r = 0.1
t = 0
while N < 10000:
    N *= (1 + r)
    t += 1
print("Population exceeds 10,000 after", t, "time steps")

# %% [markdown]
# **Exercise:** convert this re-usable program into a function.

# %% [markdown]
# ---
# **Exercises**
#
# 1. Use a `while` loop to compute the sum of the numbers from 1 to 100.
# 2. Starting from `n = 1234`, halve it repeatedly with `n = n // 2` until it reaches $0$, counting the steps.  How does the count compare with the number of binary digits of $1234$?
# 3. By the Rule of 72, an investment at $6\%$ should double in about $12$ years.  Check this with a `while` loop.  How good is the estimate at $1\%$, and at $20\%$?
# 4. Every `for` loop can be rewritten as a `while` loop.  Do this for `for i in range(5): print(i)`.  Why is the `for` version usually preferable?
#
# ---

# %% [markdown]
# ## Task 9: Errors and Debugging.
#
# Even experienced programmers make mistakes! Python will often give you feedback in the form of **error messages**. Learning to **read and interpret** error messages is an important skill.

# %% [markdown]
# ### Common Pitfalls.
#
# * Mixing up `==` (equals) and `=` (assignment).
#
# * Off-by-one errors in `range(m, n)`.  This list has `n-m` elements, starting at `m` and thus does not include `n`.
#
# * Running cells out of order.  Variables keep the values they were given in earlier cells, so a notebook that works from top to bottom can behave differently after jumping around.  When in doubt, restart the kernel and run all cells in order.
#
# * Infinite loops, due to a condition that never fails, like:
#   ```python
#   V = 1
#   while V < 2*V:
#       V += 1
#   ```

# %% [markdown]
# ### Common Types of Errors.
#
# 1. **Syntax Errors** – mistakes in the structure of the code.
#
#    ```python
#    if x = 5:   # SyntaxError
#        print("x is 5")
#    ```
#
#    Python says: `SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?`
#
#    Correct:
#
#    ```python
#    if x == 5:  # correct
#        print("x is 5")
#    ```
#
# 2. **Runtime Errors** – occur when the code runs into something impossible.
#
#    ```python
#    print(10 / 0)  # ZeroDivisionError
#    ```
#
# 3. **Name Errors** – using variables that don’t exist.
#
#    ```python
#    print(myVar)  # NameError: name 'myVar' is not defined
#    ```
#
# 4. **Type Errors** – mixing incompatible types.
#
#    ```python
#    "abc" + 5  # TypeError
#    ```

# %% [markdown]
# ### Debugging Strategies.
#
# * **Read the error message carefully** – Python usually tells you both the error type and the line number.
#
# * **Use print statements** (or better, a debugger) to check variable values.
#
# * **Test incrementally** – build code step by step instead of writing everything at once.
#
# * **Google the error message** – most likely, someone else has had the same issue.

# %% [markdown]
# ### Testing with `assert`.
#
# An `assert` statement checks that a condition is `True` and raises an `AssertionError` if it is not.  When the test passes, nothing happens at all -- which is exactly what makes assertions useful: a cell full of them that runs silently confirms that every one of them holds.

# %%
assert square(5) == 25
assert kinetic_energy(2.0, 4.0) == 16.0
assert revenue_class(-5) == "Loss"
print("all tests passed")

# %% [markdown]
# A failing assertion reports the test, not the reason:
#
# ```python
# assert square(5) == 24  # AssertionError
# ```
#
# so it pays to add a message of your own:
#
# ```python
# assert square(5) == 24, "square(5) should be 25"
# ```
#
# This is a good way to carry out the instruction *"test it with 2, 5 and 10"* in the exercises above.

# %% [markdown]
# ---
#
# **Exercises**
#
# 1. Run the following code and note the error:
#
#    ```python
#    10 / 0
#    ```
#
#    What error type do you see?
#
# 2. Try this:
#
#    ```python
#    if x = 3:
#        print("Hello")
#    ```
#
#    What does Python complain about? How do you fix it?
#
# 3. Introduce a deliberate typo (like `pritn("Hello")`). What happens? How do you correct it?
#
# 4. Write `assert` statements, each with a message of its own, that test the `cube` and
#    `convert` functions from the exercises on function definitions above.  Then change one
#    expected value so that the test fails, and read what Python reports.
#
# ---

# %% [markdown]
# ## Summary.
#
# This notebook covers some **foundations of Python programming** that we will build on throughout the course:
#
# - Using Python as a **calculator** for arithmetic and formulas.
# - Working with **variables** and **values** to store and manipulate data of different **types**.
# - Combining operations into **expressions** and reusable **functions**.
# - Using **built-in functions** and **f-strings** to compute and to present results.
# - Applying **boolean logic** and **conditionals** to make decisions.
# - Defining **recursive** functions that call themselves.
# - Using **loops** (`for`, `while`) to repeat tasks efficiently.
# - Recognizing and fixing common **errors** with simple **debugging strategies** and tests with `assert`.
